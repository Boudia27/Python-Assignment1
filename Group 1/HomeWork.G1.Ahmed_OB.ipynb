# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# read the data into a pandas DataFrame
df = pd.read_csv('C:/Users/Dell/Desktop/Group 1/Data_Group1.csv')
df.head()
# Out:
#     S1   S2   S3
# 0  450  366  382
# 1  435  372  389
# 2  441  368  378
# 3  448  371  381
# 4  442  371  372

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S1      135 non-null    int64
#  1   S2      135 non-null    int64
#  2   S3      135 non-null    int64
# dtypes: int64(3)
# memory usage: 3.3 KB

# %%
numeric_columns = df.select_dtypes(exclude = ['object'])
numeric_columns
# Out:
#       S1   S2   S3
# 0    450  366  382
# 1    435  372  389
# 2    441  368  378
# 3    448  371  381
# 4    442  371  372
# ..   ...  ...  ...
# 130  419  249  272
# 131  379  252  255
# 132  388  338  258
# 133  392  238  208
# 134  350  187  212
#
# [135 rows x 3 columns]

# %%
# compute the mean, median, and standard deviation for each sensor
mean_s1 = df['S1'].mean()
median_s1 = df['S1'].median()
std_s1 = df['S1'].std()

mean_s2 = df['S2'].mean()
median_s2 = df['S2'].median()
std_s2 = df['S2'].std()

mean_s3 = df['S3'].mean()
median_s3 = df['S3'].median()
std_s3 = df['S3'].std()

# %%
# plot a histogram of the data for each sensor 1
plt.hist(df['S1'], bins=10)
plt.title('Sensor 1')
plt.xlabel('Water Flow')
plt.ylabel('Frequency')
plt.show()

# %%
# plot a histogram of the data for each sensor 2
plt.hist(df['S2'], bins=10)
plt.title('Sensor 2')
plt.xlabel('Water Flow')
plt.ylabel('Frequency')
plt.show()

# %%
# plot a histogram of the data for each sensor 3
plt.hist(df['S3'], bins=10)
plt.title('Sensor 3')
plt.xlabel('Water Flow')
plt.ylabel('Frequency')
plt.show()

# %%
# Generate some random data
data = np.random.normal(loc=10, scale=2, size=1000)

# Calculate mean, standard deviation, median, and mode
mean = np.mean(data)
std = np.std(data)
median = np.median(data)
mode = pd.Series(data).mode()[0]

# Calculate range, percentile 25, percentile 75, and interquartile range
range_ = np.max(data) - np.min(data)
prc25 = np.percentile(data, 25)
prc75 = np.percentile(data, 75)
iqr = prc75 - prc25

# Print the results
print(f"Mean: {mean:.2f}")
print(f"Standard deviation: {std:.2f}")
print(f"Median: {median:.2f}")
print(f"Mode: {mode:.2f}")
print(f"Range: {range_:.2f}")
print(f"25th percentile: {prc25:.2f}")
print(f"75th percentile: {prc75:.2f}")
print(f"Interquartile range: {iqr:.2f}")
# Out:
# Mean: 10.08
# Standard deviation: 2.04
# Median: 10.04
# Mode: 4.23
# Range: 12.01
# 25th percentile: 8.78
# 75th percentile: 11.42
# Interquartile range: 2.64

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### Line plot of the water flow data for each sensor over time.

# %%
# Create a line plot of the data for each sensor
fig, ax = plt.subplots()
ax.plot(df['S1'], label='S1')
ax.plot(df['S2'], label='S2')
ax.plot(df['S3'], label='S3')
ax.set_xlabel('Time')
ax.set_ylabel('Water Flow')
ax.set_title('Water Flow Data from Three Sensors')
ax.legend()

plt.show()

# %%
# Create a dictionary that maps each color to a unique integer value
colors = ['Red', 'Green', 'Blue', 'Blue', 'Green', 'Red', 'Yellow', 'Orange', 'Purple', 'Blue', 'Green', 'Red', 'Blue', 'Yellow', 'Orange', 'Green', 'Blue', 'Red', 'Yellow', 'Green']
values = {'Red': 1, 'Green': 2, 'Blue': 3, 'Yellow': 4, 'Orange': 5, 'Purple': 6}

# Convert the list of colors to a list of corresponding numerical values
numerical_colors = [values[color] for color in colors]

# Calculate the quartiles
quartiles = np.quantile(numerical_colors, [0.25, 0.5, 0.75])

# Convert the quartile values
quartile_colors = [key for key, value in values.items() if value in quartiles]

print(quartile_colors)
# Out:
# ['Green', 'Blue', 'Yellow']
